# %%
print("Welcome to game !")
user_name = input("please enter your name:")
user_age  = int(input("enter your age:") )

print("hello",user_name,"you are",user_age,"years old.")

health = 10

if user_age >= 18:
    print("you are old enough to play the game !")
    play = input("Do you wants to play? yes or no: ").lower()
    
    if play == "yes":
        print("Let's play !")
        print("you are starting with",health,"health ")
        left_or_right = input("DO you want to go left or right (left/right)? ").lower()

        if left_or_right == "left":
            print("you follow the left portal and transfered to the cold planet.")
            
            option = input("welcome to cold planet. Please choose your power (ice/fire)  ")

            if option == "ice":
                print("Due to your ice ablity now you have resistance to cold with this your chances of surviving in cold planet is increased. ")
            elif option == "fire":
                print("Due to your fire ability now you have resistance to heat with this your chances of surviving in warm planet is increased.  ")

            

            wants_to = input("Do you wants to climb the mountain or moves ahead (climb/moves ahead) ")

            if wants_to == "climb":
             print("some rocks fell from the above and you fell from the mountains and lose your all healths.")
            elif wants_to == "moves ahead":
                print("let's move ahead, oh wait someone shooting fire arrows towards you. ")
                print("these guys stoles powers from anyone.")
                fight_or_not = input("Do you wants to fight these guys or not? (yes/no)  ")
                            
                if fight_or_not == "yes":
                 print("You did well by defeating these guys as a reward you gets to choose a weapon.")
                elif fight_or_not == "no":
                    print("you are killed and your power gets stolen by these guys. ")
                                 
                pick_weapon = input("please choose your weapon? (sword/blade )")
                                 
                if pick_weapon == "sword":
                    print("you received a sword, with this you can deplete anyone heatlh by two healths")
                elif pick_weapon == "blade":
                     print("you received lighting blade, with this you can deplete anyone healths by one health.")
                print("suddenly a person with dark clothes and mask is appered")
                                      
                rival = input("wants to fight or run (fight/run) ")
                if rival == "fight":
                    print("Oh this guy is strong it's better to use your weapon.")
                use_w = input("wants to use your (yes/no) ")
                                          
                if use_w == "yes":
                 print("using weapon is still not enough,you lost the battle now this man wants your five healths or still wants to fight")
                elif rival == "run":
                    print("you tries to run and get killed.")
                to_do = input("this man wants your five healths. so you wants to fight or give yours healths (fight/give healths) ")
                                               
                if to_do == "fight":
                 print("you lost the battle and killed by the mask man.")
                elif to_do == "give healths":
                 print("mask man decided to test you as a hero of this world to see that you can save this world from him. so mask man decided to give two healths instead of taking you lives. ")
                 rem_health = health+2
                 print("now you have",rem_health,"healths")
                 print("Mr.V: I never fight someone this weak Mr.hero")
                 print("there is no way someone like you is able to defeat me and if you come after me i will kill you.")
                 print("Mr.V is going to destroy this world and he is going away.") 
                 
                 go_after = input("would you like to go after him ? (yes/no) ")
                 if go_after == "yes":
                     print("it's to and die. it's time to show the difference between  the powers ")
                     print("Mr.V: I thik i told you to not to after me. do you really want to die that badly Mr.hero let's fight")
                     print("congratulation you defeat the Mr.V and save the world. thanks for playing")
                else:
                    print("you decides not to go after Mr.V and this world get's destroyed by Mr.V")

            
            
            else:
               print("oops! you choose the right portal and transfered into the space due to that you lost your all health.")
            
    else:
         print("it's okay, try this game sometime:")

else:
      print("sorry you are not old enough to play the game !")
# Out:
# Welcome to game !
# please enter your name:dy
# enter your age:12
# hello dy you are 12 years old.
# sorry you are not old enough to play the game !
